# %% [markdown]
# # Sanity Check for Data

# %%
import pandas as pd

# %%
data_path = '../Data/rotten_tomato_movie_reviews.csv'
df_rt = pd.read_csv(data_path, index_col='Name')

# %%
df_rt.head()
# Out:
#                                 Rating        Directed By             Runtime  \
# Name
# The Angry Birds Movie 2             PG   Thurop Van Orman     100 minutes
# Legend Of The Demon Cat (Kûkai)     NR         Kaige Chen     129 minutes
# Dora and the Lost City of Gold      PG        James Bobin     102 minutes
# Luce                                 R        Julius Onah     109 minutes
# Good Boys                            R    Gene Stupnitsky      95 minutes
#
#                                                 Studio TOMATOMETER score  \
# Name
# The Angry Birds Movie 2            Columbia Pictures             73%
# Legend Of The Demon Cat (Kûkai)          Well Go USA             91%
# Dora and the Lost City of Gold    Paramount Pictures             84%
# Luce                                            NEON             91%
# Good Boys                         Universal Pictures             80%
#
#                                  TOMATOMETER Count AUDIENCE score  \
# Name
# ...

# %%
data_path = '../Data/IMDB_Dataset_Cleaned.csv'
df_imdb = pd.read_csv(data_path, index_col='movie_title.1')

# %%
df_imdb.head()
# Out:
#                                               director_name  \
# movie_title.1
# Avatar                                        James Cameron
# Pirates of the Caribbean: At World's End     Gore Verbinski
# Spectre                                          Sam Mendes
# The Dark Knight Rises                     Christopher Nolan
# John Carter                                  Andrew Stanton
#
#                                           num_critic_for_reviews  duration  \
# movie_title.1
# Avatar                                                       723       178
# Pirates of the Caribbean: At World's End                     302       169
# Spectre                                                      602       148
# The Dark Knight Rises                                        813       164
# John Carter                                                  462       132
#
#                                           director_facebook_likes  \
# movie_title.1
# ...

# %%
df_rt.join(df_imdb).dropna()
# Out:
#                                                                             Rating  \
# Aladdin                                                                         PG
# Alice Through the Looking Glass   PG-13 (for sequences of sci-fi action and des...
# Anomalisa                                                                       NR
# Burn                                                                             R
# Captain America: Civil War                      R (for terror and horror violence)
# Central Intelligence                            PG-13 (for sci-fi action violence)
# Child's Play                                                                     R
# Criminal                                 R (for language throughout, and drug use)
# Domino                                                                           R
# Drive                                                                           NR
# ...
